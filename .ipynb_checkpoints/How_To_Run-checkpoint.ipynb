# %% [markdown]
# # ✅ **Your Project Folder (VERY IMPORTANT)**
#
# Create a folder like:
#
# ```
# house_price_docker/
#     main.py
#     housing.csv
#     requirements.txt
#     Dockerfile
# ```
#
# Your **main.py** must be inside this folder.
#
# ---
#
# # ⭐ STEP 1 — Create requirements.txt
#
# (Your app needs these libraries)
#
# Create **requirements.txt**:
#
# ```
# streamlit
# pandas
# numpy
# scikit-learn
# joblib
# ```
#
# (Exactly these 5 are enough)
#
# ---
#
# # ⭐ STEP 2 — Create Dockerfile
#
# (VERY IMPORTANT — this makes your app work inside Docker)
#
# Create **Dockerfile**:
#
# ```dockerfile
# # Step 1: Base image
# FROM python:3.10
#
# # Step 2: Set working directory
# WORKDIR /app
#
# # Step 3: Copy requirements
# COPY requirements.txt .
#
# # Step 4: Install dependencies
# RUN pip install --no-cache-dir -r requirements.txt
#
# # Step 5: Copy everything (main.py + csv + models)
# COPY . .
#
# # Step 6: Run Streamlit
# CMD ["streamlit", "run", "main.py", "--server.port=8501", "--server.address=0.0.0.0"]
# ```
#
# ---
#
# # ⭐ STEP 3 — Build Docker Image
#
# Open terminal inside your folder:
#
# ```
# docker build -t yash-house-price .
# ```
#
# This creates a Docker image with your entire app.
#
# ---
#
# # ⭐ STEP 4 — Run the Container
#
# ```
# docker run -p 8501:8501 yash-house-price
# ```
#
# Now open:
#
# ```
# http://localhost:8501
# ```
#
# 🎉 **Your Streamlit model will train automatically the first time**
# 🎉 **Next time it will load model.pkl and pipeline.pkl**
#
# ---
#
# # 🎯 IMPORTANT NOTE ABOUT YOUR main.py
#
# Your code trains the model **automatically** when model.pkl is missing.
#
# Docker container is **fresh every time**, so:
#
# ✔ First run → model.pkl not found → **training will run inside Docker**
# ✔ After training → prediction UI will work
#
# But if you want to skip training every time, tell me — I’ll teach you how to mount a volume so Docker saves your model.
#
# ---
#
# # 🧠 What You Achieved
#
# ✔ Docker + Streamlit
# ✔ Docker + CSV file
# ✔ Docker + ML Model training
# ✔ Docker + ML inference
# ✔ Complete end-to-end ML deployment
#
# ---

# %% [markdown]
# # So, Whenever I provide the main directory to anyone and if I tell him/her to extract my sended zip file and run using docker then it will successfully with no any library issue python issue
#
# # 🎯 THIS is the main advantage of Docker
# ### - ✔ "No installation needed"
# ### - ✔ "Same behavior everywhere"
# ### - ✔ "No dependency issues"
# ### - ✔ "Runs on any system"
# ### - ✔ "Share your project easily"
#
# #### Exactly what you said:
#
# #### “If I give this folder to anyone, they can run it using Docker without issues.”
#
# ## 👉 TRUE
# ## 💯 Exactly the point
# ## 💡 This is the beauty of Docker
# ## So, This is the Importance of Docker and power
